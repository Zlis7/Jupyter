# %%
from sympy import *
from sympy.plotting import plot
import numpy as np
import matplotlib.pyplot as plt

# %%
a5, a4, a3, a2, a1, a0 = symbols('a5,a4,a3,a2,a1,a0') 
x = Symbol('x')
y = Symbol('y')

# %%
exp1 = 6.25*a2 - 2.5*a1 + a0 - 15
exp2 = 4*a2 - 2*a1 + a0 - 10
exp3 = 2.25*a2 - 1.5*a1 + a0 - 7

# %%
nonlinsolve([exp1, exp2, exp3], [a2, a1, a0])
# Out:
# {(4.0, 8.0, 10.0)}

# %%
exp1 = -0.125*a3 + 0.25*a2 - 0.5*a1 + a0 + 15
exp2 = -a3 + a2 - a1 + a0 + 31
exp3 = a0 + 7
exp4 = 0.125*a3 + 0.25*a2 + 0.5*a1 + a0 + 4

# %%
nonlinsolve([exp1, exp2, exp3, exp4], [a3,a2, a1, a0])
# Out:
# {(4.0, -10.0, 10.0, -7.0)}

# %%
equa1 = 16*a4 - 8*a3 + 4*a2 - 2*a1 + a0 - 2
equa2 = a4 - a3 + a2 - a1 + a0 - 1
equa3 = a0 - 0
equa4 = a4 + a3 + a2 + a1 + a0 - 1
equa5 = 16*a4 + 8*a3 + 4*a2 + 2*a1 + a0 - 2
nonlinsolve([equa1, equa2, equa3, equa4, equa5], [a4, a3, a2, a1, a0])
# Out:
# {(-1/6, 0, 7/6, 0, 0)}

# %%
n = 3
ox = [x for x in range(-n, n + 1)]
oy = [-1/6*x**4 + 7/6*x**2 for x in range(-n,n + 1)]
plt.plot(ox,oy, color='gray')
plt.scatter([-2, -1, 0, 1, 2], [2,1,0,1,2], color='red')
plt.ylim(-2, 3)
plt.show()

# %%
f = -1/6*x**4 + 7/6*x**2
f.subs(x, -1)
# Out:
# 1.00000000000000

# %%
plot(f, (x, -3, 3))

# %%
solve_univariate_inequality(f > 0, x)
# Out:
# (x > -2.64575131106459) & (x < 2.64575131106459) & Ne(x, 0)

# %%
equa1 = -243*a5 + 81*a4 - 27*a3 + 9*a2 - 3*a1 + a0 - 33
equa2 = -32*a5 + 16*a4 - 8*a3 + 4*a2 - 2*a1 + a0 - 31
equa3 = -a5 + a4 - a3 + a2 - a1 + a0 - 18
equa4 = a5 + a4 + a3 + a2 + a1 + a0 + 18
equa5 = 32*a5 + 16*a4 + 8*a3 + 4*a2 + 2*a1 + a0 + 31
equa6 = 243*a5 + 81*a4 + 27*a3 + 9*a2 + 3*a1 + a0 + 33
linsolve([equa1, equa2, equa3, equa4, equa5, equa6], [a5, a4, a3, a2, a1, a0])
# Out:
# {(1/120, 0, 19/24, 0, -94/5, 0)}

# %%
n = 4
ox = [x for x in range(-n, n + 1)]
oy = [1/120*x**5 + 19/24*x**3 - 94/5*x for x in range(-n,n + 1)]
plt.plot(ox,oy, color='gray')
plt.scatter([-3, -2, -1, 1, 2, 3], [33, 31, 18, -18, -31, -33], color='red')
plt.show()

# %%
f = 1/120*x**5 + 19/24*x**3 - 94/5*x
plot(f, (x, -5,5))

# %%
solve_univariate_inequality(f < 0, x)
# Out:
# ((-oo < x) & (x < -4.43545751638198)) | ((x < 4.43545751638198) & (0 < x))

# %%
n = 10
ox = [x for x in range(n + 1)]
oy = [3*x+5 for x in range(n + 1)]

# %%
plt.plot(ox,oy, color='gray')
plt.scatter([2, 4, 8], [12.258,17.24,30.151], color='red')
plt.show()

# %%
oy[2]
# Out:
# 11

# %%
oy[4]
# Out:
# 17

# %%
oy[8]
# Out:
# 29

# %%
n = 10
ox = [x for x in range(n + 1)]
oy = [0.25*x**2+0.75*x+1.25 for x in ox]

# %%
plt.plot(ox,oy, color='gray')
plt.scatter([2, 4, 8], [3.688,10.791,20.705], color='red')
plt.show()

# %%
oy[2]
# Out:
# 3.75

# %%
oy[4]
# Out:
# 8.25

# %%
oy[8]
# Out:
# 23.25

# %%
n = 13
ox = [x for x in range(n + 1)]
oy = [0.5*x**3-0.25*x**2+0.75*x+1.25 for x in ox]

# %%
plt.plot(ox,oy, color='gray')
plt.scatter([2, 4, 8, 10, 12], [4.872,29.707,246.971,485.727, 840.658], color='red')
plt.show()

# %%
oy[2]
# Out:
# 5.75

# %%
oy[4]
# Out:
# 32.25

# %%
oy[8]
# Out:
# 247.25

# %%
oy[10]
# Out:
# 483.75

# %%
oy[12]
# Out:
# 838.25

# %%
solve_univariate_inequality(0.5*x**3-0.25*x**2+0.75*x+1.25 < 0, x)
# Out:
# (-oo < x) & (x < -0.903305383456623)

# %%
solve_univariate_inequality(0.5*x**3-0.25*x**2+0.75*x+1.25 > 0, x)
# Out:
# (-0.903305383456623 < x) & (x < oo)

# %%
solve(0.5*x**3-0.25*x**2+0.75*x+1.25)
# Out:
# [-0.903305383456623,
#  0.701652691728312 - 1.50840870048553*I,
#  0.701652691728312 + 1.50840870048553*I]

# %%
plotting.plot(0.5*x**3-0.25*x**2+0.75*x+1.25, (x, -1, 1))

# %%
plotting.plot3d((sqrt(x**2+y**2)), (x, -10000, 10000),(y, -10000, 10000))

# %%
f = -3*x + 5
plot(f,(x, -2,2))

# %%
f.subs(x, 5/3)
# Out:
# 0

# %%
f.subs(x, 2)
# Out:
# -1

# %%
f = 3*x**2 +3*x - 6
plot(f)

# %%
f.subs(x, 0.5)
# Out:
# -3.75000000000000

# %%
f.subs(x, 7)
# Out:
# 162

# %%
f3 = 2*x**4 + x**3 - 6*x**2 + 7*x + 1
plot(f3)
print(f3.subs(x, 3), '\n', f3.subs(x, -5))
# Out:
# 157
#  941

# %%
f3 = 3*sqrt(x) -10
plot(f3)

# %%
solve_univariate_inequality(f3 < 0, x)
# Out:
# (0 <= x) & (x < 100/9)

# %%
print(f3.subs(x, 64), f3.subs(x, -64))
# Out:
# 14 -10 + 24*I

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-3, -2, -1, 1, 2, 3])
    points_Y = np.array([60, 30, 19, -16, -37, -23])
    plt.xlim(-15, 15)
    plt.ylim(-40, 80)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

x = Symbol('x')
f1 = next_point[1] * x + next_point[0]
f1

print_points_ands_function1(f1)
# Out:
# MSE = 98.924305004093

# %%
MSE = 1/6 * ((-3*a1 + a0 -60)**2 + (-2*a1 + a0 -30)**2 + (-1*a1 + a0 -19)**2 + (a1 + a0 +16)**2 + (2*a1 + a0 +37)**2 + (3*a1 + a0 +23)**2)
MSE_a0 = diff(MSE, a0)
MSE_a1 = diff(MSE, a1)
MSE_grad = np.array([MSE_a0, MSE_a1])
MSE_grad
# Out:
# array([2.0*a0 + 1.11022302462516e-16*a1 - 11.0,
#        1.11022302462516e-16*a0 + 9.33333333333333*a1 + 139.333333333333],
#       dtype=object)

# %%
step = 0.01
#current_point = np.array([0, 0])
current_point = next_point
next_point = np.array([
    current_point[0] - step * MSE_grad[0].subs({a0:current_point[0], a1:current_point[1]}),
    current_point[1] - step * MSE_grad[1].subs({a0:current_point[0], a1:current_point[1]})
])
MSE.subs({a0:next_point[0], a1:next_point[1]})
# Out:
# 98.9243050040930

# %%
def print_points_ands_function2(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-3, -2, -1, 1, 2, 3])
    points_Y = np.array([-55, -40, 7, 5, 38, 53])
    plt.xlim(-5, 25)
    plt.ylim(-70, 70)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

f2 = 2 * x**3 - 121 * x**2 + 2443 * x - 16455
f3 = simplify(f2.subs(x, x+20))

print_points_ands_function2(f3)
# Out:
# MSE = 141.0

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([-15, -1, 4, -9, -2, -5, -8, 4, 13, 21])
    plt.xlim(-3, 6)
    plt.ylim(-20, 20)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

f1 = -9*x**2 + 3.375*x**3 
f2 = simplify(f1.subs(x, x/1.5))
print_points_ands_function1(f2)
# Out:
# MSE = 24.478125000000013

# %%
f1.subs(x, x/3)
# Out:
# 0.125*x**3 - x**2

# %%
def print_points_ands_function2(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-3, -2, -1, 1, 2, 3])
    points_Y = np.array([-55, -40, 7, 5, 38, 53])
    plt.xlim(-10, 10)
    plt.ylim(-70, 70)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

f2 = 0.074*x**3 - 0.11*x**2 + x + 5
f3 = simplify(f2.subs(x, 3*x))
print_points_ands_function2(f3)
# Out:
# MSE = 140.71365866666665

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([2, -4, 1, 8, 21, 40, 47, 65, 75, 92])
    plt.xlim(-6, 10)
    plt.ylim(-1, 100)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

f1 = 48 * x**2 - 128 * x + 83
f2 = simplify(f1.subs(x, x + 1.5))
f3 = simplify(f2.subs(x, x / 4))

print_points_ands_function1(f3)
# Out:
# MSE = 4.4125

# %%
def print_points_ands_function2(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([-31, -9, 4, -1, 9, 24, 47, 92, 120, 170])
    plt.xlim(-3, 6)
    plt.ylim(-35, 200)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

f2 = 4*x**3 + 30*x**2 + 74*x + 62
f3 = simplify(f2.subs(x, x - 3))
f4 = simplify(f3.subs(x, x / 1.25))
print_points_ands_function2(f4)
# Out:
# MSE = 24.89321599999993

# %%
def print_points_ands_function3(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([60, 25, 4, -0, -57, -195, -295, -540, -700, -760])
    plt.xlim(-10, 6)
    plt.ylim(-850, 100)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

f3 = -36 * x**3 - 756 * x**2 - 5334 * x - 12636
f4 = simplify(f3.subs(x, x - 6.8))
f5 = simplify(f4.subs(x, x /2))
print_points_ands_function3(f5)
# Out:
# MSE = 2184.0916452500087

# %%
def print_points_ands_function4(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([-42, -37, -23, -36, -45, -80, -83, -110, -131, -155])
    plt.xlim(-4, 20)
    plt.ylim(-160, -10)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

f4 = - 5 / 4 * x**2 + 25 * x - 152
f5 = simplify(f4.subs(x, x + 10))
f6 = simplify(f5.subs(x, x *2))
print_points_ands_function4(f6)
# Out:
# MSE = 20.3125

# %%
def print_points_ands_function1(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([-2, -1, 0, 1, 2, 3, 3.5, 4, 4.5, 5])
    points_Y = np.array([3, 1, -0.5, 1.2, 2.5, 0.8, -2, -3.5, -3, -5])
    plt.xlim(-10, 10)
    plt.ylim(-5, 5)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0], plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

f1 = 2 * x * sin(2 * x + 5) + 5 * sin(2 * x + 5) + 2
f2 = simplify(f1.subs(x, x / 1.399))
f3 = simplify(f2.subs(x, x - 4.5 ))

print_points_ands_function1(f3)
# Out:
# MSE = 7.257737553715641

# %%
def print_points_ands_function2(sympy_function):
    def function(x_): return float(sympy_function.subs(x, x_))
    
    points_X = np.array([0, 1, 2, 3, 3.5, 4, 4.5, 5, 6, 6.5, 7, 8, 9])
    points_Y = np.array([0.5, 1.2, 0.7, 1.2, 1.1, 0.7, 0.65, 0.9, 0.95, 0.3, 0.8, 0.5, 0.0])
    plt.xlim(-1, 20)
    plt.ylim(-2, 2)
    
    plt.scatter(points_X, points_Y, c='r')
    x_range = np.linspace(plt.xlim()[0] + 1, plt.xlim()[1], num=100)
    function_Y = [function(x_) for x_ in x_range]
    plt.plot(x_range, function_Y, 'b')
    plt.show()
    
    MSE = sum([(points_Y[i] - function(points_X[i]))**2 for i in range(len(points_Y))]) / len(points_Y)
    print(f'MSE = {MSE}')

f2 = sin(sqrt(3) *sqrt(x)) - 1
f3 = simplify(f2.subs(x, x + sqrt(x)))
f4 = simplify(f3.subs(x, x + 13))
print_points_ands_function2(f4)
# Out:
# MSE = 0.8552481228484059

# %%
f = x * y**2
f
# Out:
# x*y**2

# %%
diff(f, y)
# Out:
# 2*x*y

# %%
q1 = -x + 7*y + 34
q2 = 8*x + 8*y + 48
nonlinsolve([q1, q2], [x, y])
# Out:
# {(-1, -5)}

# %%
q1 = 4*x - 7*y + 4
q2 = 3*x - 4*y + 3
nonlinsolve([q1, q2], [x, y])
# Out:
# {(-1, 0)}

# %%
q1 = 5*a1 + 7*a2 - 5*a3 + 47
q2 = -2*a2 + 2*a3 - 10
q3 = -4*a1 - 8*a2 - 7*a3 - 63
nonlinsolve([q1, q2, q3], [a1, a2, a3])
# Out:
# {(-2, -6, -1)}

# %%
np.matrix([[-1,7], [8,8]]) * np.matrix([[-1],[ -5]])
# Out:
# matrix([[-34],
#         [-48]])

# %%
np.matrix([[5,7,-5], [0,-2,2], [-4,-8,-7]]) * np.matrix([[-2],[ -6],[-1]])
# Out:
# matrix([[-47],
#         [ 10],
#         [ 63]])

# %%
MSE = 1/4*((4.1 * a1 + 3.9 * a2 - 4.0)**2 + (4.7 * a1 + 4.2 * a2 - 4.3)**2 + (3.1 * a1 + 2.9 * a2 - 3.0)**2 + (4.9 * a1 + 5.0 * a2 - 4.9)**2)
MSE_a1 = diff(MSE, a1)
MSE_a2 = diff(MSE, a2)
MSE_grad = np.array([MSE_a1, MSE_a2])
MSE_grad
# Out:
# array([36.26*a1 + 34.61*a2 - 34.96, 34.61*a1 + 33.13*a2 - 33.43],
#       dtype=object)

# %%
MSE.subs({a1: 0, a2:0})
# Out:
# 16.8750000000000

# %%
#current_point = np.array([0,0])
current_point = next_point
MSE.subs({a1: current_point[0], a2:current_point[1]})
# Out:
# 0.00351375729142456

# %%
step = 0.01
next_point = np.array([current_point[0] - step * MSE_grad[0].subs({a1: current_point[0], a2:current_point[1]}), current_point[1] + step* -1 *MSE_grad[1].subs({a1: current_point[0], a2:current_point[1]})])
next_point
# Out:
# array([0.503417477853061, 0.482073365796760], dtype=object)

# %%
MSE.subs({a1: next_point[0], a2:next_point[1]})
# Out:
# 0.00340038148468236

# %%
MSE = 1/6 * ((5*a0 + 7*a1 - 5*a2 + 47)**2 + (-2*a1 + 2*a2 - 10)**2 + (-4*a0 - 8*a1 - 7*a2 - 63)**2 + (a0 + a1+ 2*a2 + 1)**2 + (2*a0 - a1 + 2*a2 + 4)**2 + (4*a0 + a1 + 4*a2 + 2)**2)
MSE_a0 = diff(MSE, a0)
MSE_a1 = diff(MSE, a1)
MSE_a2 = diff(MSE, a2)
MSE_grad = np.array([MSE_a0, MSE_a1, MSE_a2])
MSE_grad
# Out:
# array([20.6666666666667*a0 + 23.3333333333333*a1 + 8.33333333333333*a2 + 168.0,
#        23.3333333333333*a0 + 40.0*a1 + 6.99999999999999*a2 + 284.0,
#        8.33333333333333*a0 + 6.99999999999999*a1 + 34.0*a2 + 68.0],
#       dtype=object)

# %%
step = 0.01
#current_point = np.array([0,0,0])


current_point = next_point
next_point = np.array([
        current_point[0] - step * MSE_grad[0].subs({a0: current_point[0], a1:current_point[1], a2:current_point[2]}),
        current_point[1] - step * MSE_grad[1].subs({a0: current_point[0], a1:current_point[1], a2:current_point[2]}),
        current_point[2] - step * MSE_grad[2].subs({a0: current_point[0], a1:current_point[1], a2:current_point[2]})
    ])
MSE.subs({a0: next_point[0], a1:next_point[1], a2:next_point[2]})
# Out:
# 36.5242879107706
